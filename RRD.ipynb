# %%
import pandas as pd

# %%
rrd=pd.read_excel("./RRD Data.xlsx",header=2)

# %%
rrd.head()
# Out:
#    Week  Flyers  Retweets  Fbook Likes  Instagram pics  Ice Cream Price  \
# 0     1     250       250          250             250              1.0
# 1     2     250       250          250             250              1.0
# 2     3     250       250          250             250              1.0
# 3     4     250       250          250             250              1.0
# 4     5     250       250          250             250              1.0
#
#    Donut Price  I-Donut Price  Ice Cream Sales  Donut Sales  ...  Donut Units  \
# 0         1.25            2.0           1405.0      3496.25  ...       2797.0
# 1         1.25            2.0           1570.0      2412.50  ...       1930.0
# 2         1.25            2.0           1435.0      2581.25  ...       2065.0
# 3         1.25            2.0           1360.0      2675.00  ...       2140.0
# 4         1.25            2.0           1450.0      2562.50  ...       2050.0
#
# ...

# %%
rrd.columns
# Out:
# Index(['Week', 'Flyers', 'Retweets', 'Fbook Likes', 'Instagram pics',
#        'Ice Cream Price', 'Donut Price', 'I-Donut Price', 'Ice Cream Sales',
#        'Donut Sales', 'I-Donut Sales', 'Total Revenue', 'Ice Cream Units',
#        'Donut Units', 'I-Donut Units', 'Ice Cream Cost', 'Donut Cost',
#        'I-Donut Cost', 'Total Cost', 'Ice Cream Profit', 'Donut Profit',
#        'I-Donut Profit', 'Total Profit'],
#       dtype='object')
